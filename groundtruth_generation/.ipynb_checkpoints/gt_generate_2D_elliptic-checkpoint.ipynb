# %%
import numpy as np
from fipy import CellVariable, Grid2D, DiffusionTerm
from fipy.tools import numerix
import matplotlib.pyplot as plt
import pickle 


epsilon = 1/8.

L = 1
nx = 1024
dx = L/nx
mesh = Grid2D(dx=dx, dy=dx, nx=nx, ny=nx)

boundary_value = 0.

var = CellVariable(mesh=mesh, name="variable")

var.constrain(boundary_value, mesh.facesLeft)
var.constrain(boundary_value, mesh.facesRight)
var.constrain(boundary_value, mesh.facesTop)
var.constrain(boundary_value, mesh.facesBottom)

k = numerix.sin(2*np.pi*mesh.x/epsilon)*numerix.cos(2*np.pi*mesh.y/epsilon) + 2
k=1

eq = (DiffusionTerm(coeff=k)+numerix.sin(mesh.x)+numerix.cos(mesh.y)==0)

eq.solve(var=var)

# %%
gt = np.array(var).reshape(nx,nx)
plt.imshow(gt)

# %%
with open('elliptic_2D_eps_1_8.pkl', 'wb') as file: 
    pickle.dump(gt, file)

# %%
with open('elliptic_2D_eps_1_8.pkl', 'rb') as file: 
    myvar = pickle.load(file) 
  
    print(myvar)
# Out:
# [[1.27765223e-06 3.35612031e-06 5.21833450e-06 ... 8.53665547e-06
#   5.53654606e-06 2.13820914e-06]
#  [3.35565320e-06 9.32954362e-06 1.48266023e-05 ... 2.40900405e-05
#   1.52524579e-05 5.53679702e-06]
#  [5.21693120e-06 1.48247284e-05 2.38115276e-05 ... 3.85011145e-05
#   2.40910410e-05 8.53740720e-06]
#  ...
#  [3.40412420e-06 9.76408902e-06 1.57865697e-05 ... 3.04761566e-05
#   1.90304016e-05 6.72460019e-06]
#  [2.16448118e-06 6.09384081e-06 9.76439263e-06 ... 1.90278309e-05
#   1.20167551e-05 4.34562500e-06]
#  [8.07527844e-07 2.16455601e-06 3.40435020e-06 ... 6.72267116e-06
#   4.34498176e-06 1.66808476e-06]]

# %%
plt.plot(gt[500,:])
