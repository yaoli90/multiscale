# %%
import numpy as np
from fipy import CellVariable, Grid1D, DiffusionTerm
from fipy.tools import numerix
import matplotlib.pyplot as plt
import pickle 


epsilon = 1/10.

L = np.pi
nx = 1024
mesh = Grid1D(dx=L / nx, nx=nx)

valueLeft = 0.
valueRight = 0.

var = CellVariable(mesh=mesh, name="variable")

var.constrain(valueLeft, mesh.facesLeft)
var.constrain(valueRight, mesh.facesRight)

k = 0.5*numerix.sin(2*np.pi*mesh.x/epsilon) + 2

eq = (DiffusionTerm(coeff=k)+numerix.sin(mesh.x)==0)

eq.solve(var=var)

# %%
plt.plot(var)

# %%
with open('elliptic_1D_eps_1_8.pkl.pkl', 'wb') as file: 
    pickle.dump(var, file)

# %%
with open('elliptic_1D_eps_1_8.pkl.pkl', 'rb') as file: 
    myvar = pickle.load(file) 
  
    print(myvar)
# Out:
# [0.00074864 0.00221112 0.00361031 ... 0.00326171 0.00198392 0.00066851]

# %%
plt.plot(var)

# %%
x = np.linspace(0, np.pi, 257)

# %%
x[1]-x[0]
# Out:
# 0.01227184630308513

# %%
print(mesh)
# Out:
# UniformGrid1D(dx=0.01227184630308513, nx=256)

# %%
mesh.cellCenters
# Out:
# CellVariable(value=array([[0.00613592, 0.01840777, 0.03067962, 0.04295146, 0.05522331,
#         0.06749515, 0.079767  , 0.09203885, 0.10431069, 0.11658254,
#         0.12885439, 0.14112623, 0.15339808, 0.16566993, 0.17794177,
#         0.19021362, 0.20248546, 0.21475731, 0.22702916, 0.239301  ,
#         0.25157285, 0.2638447 , 0.27611654, 0.28838839, 0.30066023,
#         0.31293208, 0.32520393, 0.33747577, 0.34974762, 0.36201947,
#         0.37429131, 0.38656316, 0.398835  , 0.41110685, 0.4233787 ,
#         0.43565054, 0.44792239, 0.46019424, 0.47246608, 0.48473793,
#         0.49700978, 0.50928162, 0.52155347, 0.53382531, 0.54609716,
#         0.55836901, 0.57064085, 0.5829127 , 0.59518455, 0.60745639,
#         0.61972824, 0.63200008, 0.64427193, 0.65654378, 0.66881562,
#         0.68108747, 0.69335932, 0.70563116, 0.71790301, 0.73017486,
#         0.7424467 , 0.75471855, 0.76699039, 0.77926224, 0.79153409,
#         0.80380593, 0.81607778, 0.82834963, 0.84062147, 0.85289332,
#         0.86516516, 0.87743701, 0.88970886, 0.9019807 , 0.91425255,
#         0.9265244 , 0.93879624, 0.95106809, 0.96333993, 0.97561178,
#         0.98788363, 1.00015547, 1.01242732, 1.02469917, 1.03697101,
#         1.04924286, 1.06151471, 1.07378655, 1.0860584 , 1.09833024,
